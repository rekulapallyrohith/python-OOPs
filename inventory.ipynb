# %%
class Product:
    def __init__(self, id:str, name:str, price:float):
        self.__id = id
        self.__name = name
        self.__price = price
    @property
    def id(self):
        return self.__id
    @property
    def name(self):
        return self.__name
    @property
    def price(self):
        return self.__price
    @price.setter
    def price(self, value:float):
        self.__price = value
    def __repr__(self):
        return f"{self.__name}\n {self.__id}\n {self.__price}"

# %%
p = Product(id = "b1001", name="Aquafina1ltr", price= 20)

# %%
p

# %%
p
# Out:
# Aquafina1ltr

# %%
p
# Out:
# Aquafina1ltr
#  b1001
#  20

# %%
str(p)
# Out:
# 'Aquafina1ltr\n b1001\n 20'

# %%
from dataclasses import dataclass

@dataclass
class Product:
    id:str
    name:str
    price:float

# %%
p = Product(id="B1001", name="Bisleri", price=20)

# %%
p
# Out:
# Product(id='B1001', name='Bisleri', price=20)

# %%
p.id
# Out:
# 'B1001'

# %%
p.name
# Out:
# 'Bisleri'

# %%
p.__dict__
# Out:
# {'id': 'B1001', 'name': 'Bisleri', 'price': 20}

# %%
@dataclass
class WarehouseItem(Product):
    quantity:int

# %%
w = WarehouseItem(id="W1001", name="Bisleri", price= 20, quantity= 100)

# %%
class Warehouse:
    def __init__(self, id:str, name:str, location:str):
        self.id = id
        self.name = name
        self.location = location
        self.items:list[WarehouseItem]= []
    def procure_item(self, item:WarehouseItem): pass
    def sell_item(self, item_id:str, quantity:int): pass
    def find_item_by_id(self, item_id:str): pass
    def find_item_by_name(self, name:str): pass

# %% [markdown]
# Liskov substitution Principle

# %%
class Bird:
    def fly(self):
        print("i can fly")

# %%
class Penguin(Bird):
    def fly(self):
        raise Exception("Penguins can't fly!")

# %%
def make_bird_fly(bird:Bird):
    return bird.fly()

# %%
issubclass(Penguin, Bird)
# Out:
# True

# %%
def drive(v:Vehicle):

# %%
class Vehicle:
        pass

# %%
class Bike(Vehicle):
    pass

# %%
def drive(v:Vehicle):
    pass

# %%
make_bird_fly(Bird())
# Out:
# i can fly

# %%
make_bird_fly(Penguin())
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 make_bird_fly(Penguin())
#
# Cell In[45], line 2, in make_bird_fly(bird)
#       1 def make_bird_fly(bird:Bird):
# ----> 2     return bird.fly()
#
# Cell In[63], line 3, in Penguin.fly(self)
#       2 def fly(self):
# ----> 3     raise Exception("Penguins can't fly!")
#
# Exception: Penguins can't fly!

# %%
class Eagle(Bird):
    pass

# %%
make_bird_fly(Eagle())
# Out:
# i can fly

# %%
class Bird:
    pass  # Base class does not assume flying

class FlyingBird(Bird):
    def fly(self):
        print("I can fly!")

class Penguin(Bird):
    def swim(self):
        print("I can swim!")

# %%
def let_bird_fly(bird: FlyingBird):
    bird.fly()

# %%
let_bird_fly(FlyingBird())
# Out:
# I can fly!

# %%
let_bird_fly(Penguin())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 let_bird_fly(Penguin())
#
# Cell In[66], line 2, in let_bird_fly(bird)
#       1 def let_bird_fly(bird: FlyingBird):
# ----> 2     bird.fly()
#
# AttributeError: 'Penguin' object has no attribute 'fly'

# %% [markdown]
# Duck Typing

# %%
class Bird:
    def fly(self):
        print("Bird is flying")

# %%
class Eagle(Bird):pass

# %%
class Plane:
    def fly(slef):
        print("Plane is flying")

# %%
def make_it_fly(bird):
    bird.fly()

# %%
b = Bird()
e = Eagle()
p = Plane()

# %%
make_it_fly(b)
# Out:
# Bird is flying

# %%
make_it_fly(e)
# Out:
# Eagle is flying

# %%
make_it_fly(p)
# Out:
# Plane is flying

# %%
class Car:
    pass

# %%
c = Car()

# %%
make_it_fly(c)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 make_it_fly(c)
#
# Cell In[71], line 2, in make_it_fly(bird)
#       1 def make_it_fly(bird):
# ----> 2     bird.fly()
#
# AttributeError: 'Car' object has no attribute 'fly'

# %% [markdown]
# Python Context Manager

# %%
__enter__
__exit__

# %%
class ContextManager:
    def __init__(self):
        print("init method called")
    def __enter__(self):
        print("enter method is called")
        return self
    def print_details(self):
        print("am context manager")
    def __exit__(self, exc_type, exc_val, exc_tb):
        print("exit method is called")

# %%
with ContextManager() as c :
    c.print_details()
# Out:
# init method called
# enter method is called
# am context manager
# exit method is called

# %% [markdown]
# Python File Management

# %%
builtins.pyi

# %%
open()

notes.txt

# %%
file = open("notes.txt", mode="w")

# %%
with open("notes.txt", mode="w") as file:
    file.write("hello\n")
    file.write("hai\n")
    file.write("am doing good")

# %%
with open("notes.txt", mode="r") as file:
    file.writelines(["\nhello\n", "hai"])
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[123], line 2
#       1 with open("notes.txt", mode="r") as file:
# ----> 2     file.writelines(["\nhello\n", "hai"])
#
# UnsupportedOperation: not writable

# %%
with open("notes.txt", mode="r") as f:
    for line in f.readlines():
        print(line)
# Out:
# hello
#
# hai
#
# am doing good

# %% [markdown]
# ### Comma Seperated Values (CSV)
